# %% [markdown]
# # Calcul des impacts environnementaux et socio-économiques par métal et scénario
#
# Ce notebook calcule les impacts LCA environnementaux (`Total EQ`, `Total HH`) et socio-économiques (`Labor rights`, `Health & safety`, `Society`, `Employment`, `IO multiplier`) pour chaque combinaison de métal, scénario de demande et typologie d'approvisionnement.
#
# **Logique de calcul :**
# Pour chaque ligne de `DEMAND`, on multiplie les quantités des colonnes :
# - `Refining CAN (mining CAN)`
# - `Refining RoW (mining CAN)`
# - `Refining RoW (mining RoW)`
#
# ...par les facteurs d'impact correspondants dans `Env_LCA` et `Social_eco_LCA`, en faisant correspondre le métal et le `Details`.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

FILE_PATH = 'For_SAM.xlsx'

# %% [markdown]
# ## 1. Chargement des données

# %%
df_demand = pd.read_excel(FILE_PATH, sheet_name='Demand')
df_env    = pd.read_excel(FILE_PATH, sheet_name='Env_LCA')
df_soc    = pd.read_excel(FILE_PATH, sheet_name='Social_eco_LCA')

print(f"Demand     : {df_demand.shape}")
print(f"Env_LCA    : {df_env.shape}")
print(f"Social_eco : {df_soc.shape}")
# Out:
# Demand     : (1440, 12)
# Env_LCA    : (23, 6)
# Social_eco : (9, 12)

# %%
# On filtre pour uniquement garder Copper, Nickel, Cobalt dans la demand
df_demand = df_demand[df_demand['Metal'].isin(['Copper', 'Nickel', 'Cobalt'])]

# %%
print("=== Colonnes Demand ===")
print(df_demand.columns.tolist())
print("\n=== Colonnes Env_LCA ===")
print(df_env.columns.tolist())
print("\n=== Colonnes Social_eco_LCA ===")
print(df_soc.columns.tolist())
# Out:
# === Colonnes Demand ===
# ['Year', 'Metal', 'Demand scenario CER', 'Production scenario CCI', 'Production scenario CCI|Refining CAN share', 'Supply scenario', 'Demand_value_t', 'Mining CAN', 'Mining RoW', 'Refining CAN (mining CAN)', 'Refining RoW (mining CAN)', 'Refining RoW (mining RoW)']
#
# === Colonnes Env_LCA ===
# ['Commodity', 'Geography', 'Reference point', 'Details', 'Total EQ (PDF.m2.yr)', 'Total HH (DALY)']
#
# === Colonnes Social_eco_LCA ===
# ['Metal', 'Details', '1 Labor rights & decent work', '2 Health & safety', '3 Society', 'Employment (Global) (full time job equivalent/CAD)', 'IO multiplier (Global economy)', 'Labor rights & decent work (physique)', 'Health & safety (physique)', 'Society (physique)', 'Employment (physique)', 'IO multiplier (physique)']

# %%
print("=== Métaux dans Demand ===", df_demand['Metal'].unique())
print("\n=== Métaux dans Env_LCA ===", df_env['Commodity'].dropna().unique())
print("\n=== Métaux dans Social_eco_LCA ===", df_soc['Metal'].dropna().unique())
# Out:
# === Métaux dans Demand === ['Cobalt' 'Copper' 'Nickel']
#
# === Métaux dans Env_LCA === ['Cobalt' 'Copper' 'Nickel']
#
# === Métaux dans Social_eco_LCA === ['Copper' 'Nickel' 'Cobalt']

# %% [markdown]
# ## 2. Construction des tables de facteurs d'impact
#
# On filtre les lignes sans `Commodity`/`Metal` (lignes agrégées) et on indexe par `(métal, Details)` pour un lookup rapide.

# %%
# Env_LCA : garder uniquement les lignes avec un Details correspondant aux 3 typologies
supply_types = ['Refining CAN (mining CAN)', 'Refining RoW (mining CAN)', 'Refining RoW (mining RoW)']

env_factors = (
    df_env[df_env['Details'].isin(supply_types)]
    .set_index(['Commodity', 'Details'])
    [['Total EQ (PDF.m2.yr)', 'Total HH (DALY)']]
)
print("Facteurs environnementaux disponibles :")
print(env_factors)
# Out:
# Facteurs environnementaux disponibles :
#                                      Total EQ (PDF.m2.yr)  Total HH (DALY)
# Commodity Details
# Cobalt    Refining CAN (mining CAN)              8.342655         0.000077
#           Refining RoW (mining CAN)              8.880526         0.000082
#           Refining RoW (mining RoW)              8.932025         0.000083
# Copper    Refining CAN (mining CAN)             47.250492         0.000036
#           Refining RoW (mining CAN)             52.212409         0.000057
#           Refining RoW (mining RoW)             49.587501         0.000058
# Nickel    Refining CAN (mining CAN)              3.753558         0.000036
#           Refining RoW (mining CAN)              4.166736         0.000040
#           Refining RoW (mining RoW)              4.273833         0.000041

# %%
# Social_eco_LCA : indexé par (Metal, Details)
soc_cols = [
    'Labor rights & decent work (physique)',
    'Health & safety (physique)',
    'Society (physique)',
    'Employment (physique)',
    'IO multiplier (physique)'
]

soc_factors = (
    df_soc[df_soc['Details'].isin(supply_types)]
    .set_index(['Metal', 'Details'])
    [soc_cols]
)
print("Facteurs socio-économiques disponibles :")
print(soc_factors)
# Out:
# Facteurs socio-économiques disponibles :
#                                   Labor rights & decent work (physique)  \
# Metal  Details
# Copper Refining CAN (mining CAN)                               0.197810
#        Refining RoW (mining CAN)                               0.327726
#        Refining RoW (mining RoW)                               0.570953
# Nickel Refining CAN (mining CAN)                               0.446936
#        Refining RoW (mining CAN)                               0.740470
#        Refining RoW (mining RoW)                               2.422883
# Cobalt Refining CAN (mining CAN)                               0.267735
#        Refining RoW (mining CAN)                               0.955587
#        Refining RoW (mining RoW)                               1.105743
#
#                                   Health & safety (physique)  \
# Metal  Details
# Copper Refining CAN (mining CAN)                    0.357567
#        Refining RoW (mining CAN)                    0.593010
#        Refining RoW (mining RoW)                    0.947348
# Nickel Refining CAN (mining CAN)                    0.807893
#        Refining RoW (mining CAN)                    1.339858
#        Refining RoW (mining RoW)                    5.404673
# Cobalt Refining CAN (mining CAN)                    0.483964
#        Refining RoW (mining CAN)                    1.798600
#        Refining RoW (mining RoW)                    2.041284
#
#                                   Society (physique)  Employment (physique)  \
# Metal  Details
# Copper Refining CAN (mining CAN)            0.115964               0.000078
#        Refining RoW (mining CAN)            0.226286               0.000207
#        Refining RoW (mining RoW)            0.498747               0.000736
# Nickel Refining CAN (mining CAN)            0.262012              10.952225
#        Refining RoW (mining CAN)            0.511276              18.163814
#        Refining RoW (mining RoW)            1.984167              73.268565
# Cobalt Refining CAN (mining CAN)            0.156957               0.000085
#        Refining RoW (mining CAN)            0.762815               0.000160
#        Refining RoW (mining RoW)            0.890040               0.001159
#
#                                   IO multiplier (physique)
# Metal  Details
# Copper Refining CAN (mining CAN)                 11.253167
#        Refining RoW (mining CAN)                 10.970671
#        Refining RoW (mining RoW)                 11.776331
# Nickel Refining CAN (mining CAN)                  3.551966
#        Refining RoW (mining CAN)                  6.931121
#        Refining RoW (mining RoW)                 26.898398
# Cobalt Refining CAN (mining CAN)                 12.697223
#        Refining RoW (mining CAN)                 12.892438
#        Refining RoW (mining RoW)                 16.224790

# %% [markdown]
# ## 3. Calcul des impacts
#
# Pour chaque ligne de `DEMAND` et chaque typologie d'approvisionnement :
#
# $$\text{Impact}_{i} = Q_{i} \times f_{\text{métal, typologie}}$$
#
# Les impacts des 3 typologies sont **sommés** pour obtenir l'impact total de la ligne.

# %%
# Colonnes de quantité dans Demand, associées à chaque Details
demand_qty_map = {
    'Refining CAN (mining CAN)': 'Refining CAN (mining CAN)',
    'Refining RoW (mining CAN)': 'Refining RoW (mining CAN)',
    'Refining RoW (mining RoW)': 'Refining RoW (mining RoW)',
}

env_output_cols  = ['Total EQ (PDF.m2.yr)', 'Total HH (DALY)']
soc_output_cols  = soc_cols
key_cols         = ['Year', 'Metal', 'Demand scenario CER', 'Production scenario CCI',
                    'Production scenario CCI|Refining CAN share', 'Supply scenario']

results = []

for _, row in df_demand.iterrows():
    metal = row['Metal']
    record = {c: row[c] for c in key_cols}

    env_total  = {c: 0.0 for c in env_output_cols}
    soc_total  = {c: 0.0 for c in soc_output_cols}

    for details, qty_col in demand_qty_map.items():
        qty = row.get(qty_col, 0)
        if pd.isna(qty) or qty == 0:
            continue

        # -- Impact environnemental --
        try:
            ef = env_factors.loc[(metal, details)]
            for c in env_output_cols:
                env_total[c] += qty * ef[c]
        except KeyError:
            pass  # métal sans facteur env pour cette typologie (ex. Graphite, Lithium)

        # -- Impact socio-économique --
        try:
            sf = soc_factors.loc[(metal, details)]
            for c in soc_output_cols:
                soc_total[c] += qty * sf[c]
        except KeyError:
            pass

    record.update(env_total)
    record.update(soc_total)
    results.append(record)

df_results = pd.DataFrame(results)
print(f"Résultats calculés : {df_results.shape[0]} lignes")
df_results.head()
# Out:
# Résultats calculés : 720 lignes
#    Year   Metal Demand scenario CER Production scenario CCI  \
# 0  2025  Cobalt     Canada Net-zero     Existing production
# 1  2025  Cobalt     Canada Net-zero     Existing production
# 2  2025  Cobalt     Canada Net-zero    Production potential
# 3  2025  Cobalt     Canada Net-zero    Production potential
# 4  2025  Cobalt     Canada Net-zero    Production potential
#
#   Production scenario CCI|Refining CAN share  \
# 0                             Current shares
# 1                             Current shares
# 2                             Current shares
# 3                             Current shares
# 4                                   100% CAN
#
#                     Supply scenario  Total EQ (PDF.m2.yr)  Total HH (DALY)  \
# 0                             NIMBY          85357.295501         0.788477
# 1                        Status Quo          84481.066104         0.780520
# 2              Expansion Extractive          84391.686178         0.779708
# 3  Expansion Extractive+Circularity          84391.686178         0.779708
# 4                        Integrated          84360.279669         0.779425
#
#    Labor rights & decent work (physique)  Health & safety (physique)  \
# 0                           10566.831042                19507.167443
# 1                            9316.870701                17186.218213
# 2                            9189.368287                16949.469398
# 3                            9189.368287                16949.469398
# 4                            9149.204313                16872.707290
#
#    Society (physique)  Employment (physique)  IO multiplier (physique)
# 0         8505.503802              11.071711             155049.295968
# 1         7412.266896               9.428265             149644.552318
# 2         7300.751082               9.260626             149093.240536
# 3         7300.751082               9.260626             149093.240536
# 4         7265.374788               9.256243             149081.841886

# %%
df_results
# Out:
#      Year   Metal Demand scenario CER Production scenario CCI  \
# 0    2025  Cobalt     Canada Net-zero     Existing production
# 1    2025  Cobalt     Canada Net-zero     Existing production
# 2    2025  Cobalt     Canada Net-zero    Production potential
# 3    2025  Cobalt     Canada Net-zero    Production potential
# 4    2025  Cobalt     Canada Net-zero    Production potential
# ..    ...     ...                 ...                     ...
# 715  2040  Nickel     Global Net-zero     Existing production
# 716  2040  Nickel     Global Net-zero     Existing production
# 717  2040  Nickel     Global Net-zero    Production potential
# 718  2040  Nickel     Global Net-zero    Production potential
# 719  2040  Nickel     Global Net-zero    Production potential
#
#     Production scenario CCI|Refining CAN share  \
# 0                               Current shares
# 1                               Current shares
# 2                               Current shares
# 3                               Current shares
# 4                                     100% CAN
# ..                                         ...
# 715                             Current shares
# 716                             Current shares
# 717                             Current shares
# 718                             Current shares
# 719                                   100% CAN
#
#                       Supply scenario  Total EQ (PDF.m2.yr)  Total HH (DALY)  \
# 0                               NIMBY          85357.295501         0.788477
# 1                          Status Quo          84481.066104         0.780520
# 2                Expansion Extractive          84391.686178         0.779708
# 3    Expansion Extractive+Circularity          84391.686178         0.779708
# 4                          Integrated          84360.279669         0.779425
# ..                                ...                   ...              ...
# 715                             NIMBY         831149.125562         7.896926
# 716                        Status Quo         819804.105853         7.793536
# 717              Expansion Extractive         744939.989637         7.111373
# 718  Expansion Extractive+Circularity         744939.989637         7.111373
# 719                        Integrated         729969.243283         6.976534
#
#      Labor rights & decent work (physique)  Health & safety (physique)  \
# 0                             10566.831042                1.950717e+04
# 1                              9316.870701                1.718622e+04
# 2                              9189.368287                1.694947e+04
# 3                              9189.368287                1.694947e+04
# 4                              9149.204313                1.687271e+04
# ..                                     ...                         ...
# 715                          471187.684078                1.051068e+06
# 716                          421573.237318                9.348745e+05
# 717                           97553.092467                1.763890e+05
# 718                           97553.092467                1.763890e+05
# 719                           86917.421423                1.571142e+05
#
#      Society (physique)  Employment (physique)  IO multiplier (physique)
# 0           8505.503802           1.107171e+01              1.550493e+05
# 1           7412.266896           9.428265e+00              1.496446e+05
# 2           7300.751082           9.260626e+00              1.490932e+05
# 3           7300.751082           9.260626e+00              1.490932e+05
# 4           7265.374788           9.256243e+00              1.490818e+05
# ..                  ...                    ...                       ...
# 715       385868.721166           1.424883e+07              5.231038e+06
# 716       342593.184804           1.267365e+07              4.644372e+06
# 717        59986.061405           2.391221e+06              8.132023e+05
# 718        59986.061405           2.391221e+06              8.132023e+05
# 719        50954.436105           2.129922e+06              6.907649e+05
#
# [720 rows x 13 columns]

# %%
df_results.to_excel(r"results_demand_lca_for_SAM.xlsx")

# %%
# Enlever le scénario supply de circularité pour le moment
df_results = df_results[df_results['Supply scenario'] != 'Expansion Extractive+Circularity'].copy()

# %% [markdown]
# # 4. Visualisations

# %% [markdown]
# ## 4.1 Préparation des données pour les graphiques

# %%
# ── Colonnes d'impact ──────────────────────────────────────────────────────────
IMPACT_COLS = [
    'Total EQ (PDF.m2.yr)',
    'Total HH (DALY)',
    'Labor rights & decent work (physique)',
    'Health & safety (physique)',
    'Society (physique)',
    'Employment (physique)',
    'IO multiplier (physique)',
]

# Noms courts pour les axes
IMPACT_LABELS = {
    'Total EQ (PDF.m2.yr)'                  : 'EQ\n(PDF.m2.yr)',
    'Total HH (DALY)'                        : 'HH\n(DALY)',
    'Labor rights & decent work (physique)'  : 'Labor\nrights',
    'Health & safety (physique)'             : 'Health\n& safety',
    'Society (physique)'                     : 'Society',
    'Employment (physique)'                  : 'Employment',
    'IO multiplier (physique)'               : 'IO\nmultiplier',
}

KEY_COLS = ['Year', 'Metal', 'Demand scenario CER',
            'Production scenario CCI', 'Production scenario CCI|Refining CAN share',
            'Supply scenario']

# %%
# Filtrer la période 2025–2040
df_period = df_results[(df_results['Year'] >= 2025) & (df_results['Year'] <= 2040)].copy()

GROUP_COLS = ['Metal', 'Demand scenario CER',
              'Production scenario CCI', 'Production scenario CCI|Refining CAN share',
              'Supply scenario']

df_cum = (
    df_period
    .groupby(GROUP_COLS)[IMPACT_COLS]
    .sum()
    .reset_index()
)
# Out:
# Lignes cumulées : 36
#     Metal Demand scenario CER Production scenario CCI  \
# 0  Cobalt     Canada Net-zero     Existing production
# 1  Cobalt     Canada Net-zero     Existing production
# 2  Cobalt     Canada Net-zero    Production potential
# 3  Cobalt     Canada Net-zero    Production potential
# 4  Cobalt    Current Measures     Existing production
#
#   Production scenario CCI|Refining CAN share       Supply scenario  \
# 0                             Current shares                 NIMBY
# 1                             Current shares            Status Quo
# 2                                   100% CAN            Integrated
# 3                             Current shares  Expansion Extractive
# 4                             Current shares                 NIMBY
#
#    Total EQ (PDF.m2.yr)  Total HH (DALY)  \
# 0          1.642355e+07       151.710355
# 1          1.641252e+07       151.610231
# 2          1.636788e+07       151.204971
# 3          1.636963e+07       151.220748
# 4          6.647505e+06        61.405440
#
#    Labor rights & decent work (physique)  Health & safety (physique)  \
# 0                           2.033158e+06                3.753363e+06
# 1                           2.017430e+06                3.724159e+06
# 2                           1.954004e+06                3.606267e+06
# 3                           1.956247e+06                3.610553e+06
# 4                           8.229298e+05                1.519191e+06
#
#    Society (physique)  Employment (physique)  IO multiplier (physique)
# 0        1.636539e+06            2130.301852              2.983295e+07
# 1        1.622783e+06            2109.622376              2.976494e+07
# 2        1.567296e+06            2028.934073              2.949975e+07
# 3        1.569271e+06            2029.178782              2.950039e+07
# 4        6.623966e+05             862.249139              1.207502e+07

# %%
df_cum
# Out:
#      Metal Demand scenario CER Production scenario CCI  \
# 0   Cobalt     Canada Net-zero     Existing production
# 1   Cobalt     Canada Net-zero     Existing production
# 2   Cobalt     Canada Net-zero    Production potential
# 3   Cobalt     Canada Net-zero    Production potential
# 4   Cobalt    Current Measures     Existing production
# 5   Cobalt    Current Measures     Existing production
# 6   Cobalt    Current Measures    Production potential
# 7   Cobalt    Current Measures    Production potential
# 8   Cobalt     Global Net-zero     Existing production
# 9   Cobalt     Global Net-zero     Existing production
# 10  Cobalt     Global Net-zero    Production potential
# 11  Cobalt     Global Net-zero    Production potential
# 12  Copper     Canada Net-zero     Existing production
# 13  Copper     Canada Net-zero     Existing production
# 14  Copper     Canada Net-zero    Production potential
# 15  Copper     Canada Net-zero    Production potential
# 16  Copper    Current Measures     Existing production
# 17  Copper    Current Measures     Existing production
# 18  Copper    Current Measures    Production potential
# 19  Copper    Current Measures    Production potential
# 20  Copper     Global Net-zero     Existing production
# 21  Copper     Global Net-zero     Existing production
# 22  Copper     Global Net-zero    Production potential
# 23  Copper     Global Net-zero    Production potential
# 24  Nickel     Canada Net-zero     Existing production
# 25  Nickel     Canada Net-zero     Existing production
# 26  Nickel     Canada Net-zero    Production potential
# 27  Nickel     Canada Net-zero    Production potential
# 28  Nickel    Current Measures     Existing production
# 29  Nickel    Current Measures     Existing production
# 30  Nickel    Current Measures    Production potential
# 31  Nickel    Current Measures    Production potential
# 32  Nickel     Global Net-zero     Existing production
# 33  Nickel     Global Net-zero     Existing production
# 34  Nickel     Global Net-zero    Production potential
# 35  Nickel     Global Net-zero    Production potential
#
#    Production scenario CCI|Refining CAN share       Supply scenario  \
# 0                              Current shares                 NIMBY
# 1                              Current shares            Status Quo
# 2                                    100% CAN            Integrated
# 3                              Current shares  Expansion Extractive
# 4                              Current shares                 NIMBY
# 5                              Current shares            Status Quo
# 6                                    100% CAN            Integrated
# 7                              Current shares  Expansion Extractive
# 8                              Current shares                 NIMBY
# 9                              Current shares            Status Quo
# 10                                   100% CAN            Integrated
# 11                             Current shares  Expansion Extractive
# 12                             Current shares                 NIMBY
# 13                             Current shares            Status Quo
# 14                                   100% CAN            Integrated
# 15                             Current shares  Expansion Extractive
# 16                             Current shares                 NIMBY
# 17                             Current shares            Status Quo
# 18                                   100% CAN            Integrated
# 19                             Current shares  Expansion Extractive
# 20                             Current shares                 NIMBY
# 21                             Current shares            Status Quo
# 22                                   100% CAN            Integrated
# 23                             Current shares  Expansion Extractive
# 24                             Current shares                 NIMBY
# 25                             Current shares            Status Quo
# 26                                   100% CAN            Integrated
# 27                             Current shares  Expansion Extractive
# 28                             Current shares                 NIMBY
# 29                             Current shares            Status Quo
# 30                                   100% CAN            Integrated
# 31                             Current shares  Expansion Extractive
# 32                             Current shares                 NIMBY
# 33                             Current shares            Status Quo
# 34                                   100% CAN            Integrated
# 35                             Current shares  Expansion Extractive
#
#     Total EQ (PDF.m2.yr)  Total HH (DALY)  \
# 0           1.642355e+07       151.710355
# 1           1.641252e+07       151.610231
# 2           1.636788e+07       151.204971
# 3           1.636963e+07       151.220748
# 4           6.647505e+06        61.405440
# 5           6.636479e+06        61.305316
# 6           6.591836e+06        60.900057
# 7           6.593590e+06        60.915833
# 8           1.563139e+07       144.392846
# 9           1.562036e+07       144.292722
# 10          1.557572e+07       143.887462
# 11          1.557747e+07       143.903239
# 12          9.527231e+08      1106.347640
# 13          9.506336e+08      1048.070070
# 14          9.278108e+08       872.935977
# 15          9.473992e+08       957.860077
# 16          8.010604e+08       930.229681
# 17          7.989709e+08       871.952111
# 18          7.761481e+08       696.818019
# 19          7.957365e+08       781.742118
# 20          9.154913e+08      1063.112296
# 21          9.134018e+08      1004.834725
# 22          8.905790e+08       829.700633
# 23          9.101674e+08       914.624732
# 24          7.842852e+06        74.516618
# 25          7.403153e+06        70.512127
# 26          6.888103e+06        65.831650
# 27          6.997085e+06        66.814459
# 28          3.485042e+06        33.112130
# 29          3.155541e+06        30.113778
# 30          3.060790e+06        29.252887
# 31          3.060790e+06        29.252887
# 32          7.513624e+06        71.388560
# 33          7.081092e+06        67.449441
# 34          6.598954e+06        63.068170
# 35          6.682767e+06        63.823068
#
#     Labor rights & decent work (physique)  Health & safety (physique)  \
# 0                            2.033158e+06                3.753363e+06
# 1                            2.017430e+06                3.724159e+06
# 2                            1.954004e+06                3.606267e+06
# 3                            1.956247e+06                3.610553e+06
# 4                            8.229298e+05                1.519191e+06
# 5                            8.072015e+05                1.489986e+06
# 6                            7.437757e+05                1.372094e+06
# 7                            7.460183e+05                1.376380e+06
# 8                            1.935092e+06                3.572326e+06
# 9                            1.919364e+06                3.543121e+06
# 10                           1.855938e+06                3.425229e+06
# 11                           1.858181e+06                3.429515e+06
# 12                           1.096970e+07                1.820136e+07
# 13                           9.609854e+06                1.609866e+07
# 14                           6.992026e+06                1.191434e+07
# 15                           7.504903e+06                1.284381e+07
# 16                           9.223447e+06                1.530391e+07
# 17                           7.863603e+06                1.320121e+07
# 18                           5.245775e+06                9.016893e+06
# 19                           5.758651e+06                9.946365e+06
# 20                           1.054101e+07                1.749006e+07
# 21                           9.181166e+06                1.538736e+07
# 22                           6.563338e+06                1.120305e+07
# 23                           7.076214e+06                1.213252e+07
# 24                           4.446200e+06                9.918041e+06
# 25                           2.613618e+06                5.635541e+06
# 26                           8.201662e+05                1.482554e+06
# 27                           9.394932e+05                1.725306e+06
# 28                           1.975709e+06                4.407171e+06
# 29                           6.893354e+05                1.410457e+06
# 30                           3.644482e+05                6.587863e+05
# 31                           3.644482e+05                6.587863e+05
# 32                           4.259557e+06                9.501701e+06
# 33                           2.460507e+06                5.297954e+06
# 34                           7.857373e+05                1.420319e+06
# 35                           8.452810e+05                1.528229e+06
#
#     Society (physique)  Employment (physique)  IO multiplier (physique)
# 0         1.636539e+06           2.130302e+03              2.983295e+07
# 1         1.622783e+06           2.109622e+03              2.976494e+07
# 2         1.567296e+06           2.028934e+03              2.949975e+07
# 3         1.569271e+06           2.029179e+03              2.950039e+07
# 4         6.623966e+05           8.622491e+02              1.207502e+07
# 5         6.486404e+05           8.415697e+02              1.200701e+07
# 6         5.931532e+05           7.608814e+02              1.174182e+07
# 7         5.951285e+05           7.611261e+02              1.174246e+07
# 8         1.557603e+06           2.027550e+03              2.839400e+07
# 9         1.543847e+06           2.006871e+03              2.832600e+07
# 10        1.488360e+06           1.926182e+03              2.806081e+07
# 11        1.490335e+06           1.926427e+03              2.806144e+07
# 12        9.582401e+06           1.414336e+04              2.262583e+08
# 13        8.151869e+06           1.158877e+04              2.236318e+08
# 14        5.501971e+06           7.122734e+03              2.206814e+08
# 15        5.937497e+06           7.634415e+03              2.195662e+08
# 16        8.056992e+06           1.189190e+04              1.902405e+08
# 17        6.626460e+06           9.337304e+03              1.876141e+08
# 18        3.976562e+06           4.871272e+03              1.846637e+08
# 19        4.412087e+06           5.382953e+03              1.835484e+08
# 20        9.207927e+06           1.359065e+04              2.174163e+08
# 21        7.777395e+06           1.103605e+04              2.147898e+08
# 22        5.127497e+06           6.570021e+03              2.118394e+08
# 23        5.563023e+06           7.081702e+03              2.107241e+08
# 24        3.641117e+06           1.344541e+08              4.936088e+07
# 25        2.043076e+06           7.639833e+07              2.769700e+07
# 26        4.808139e+05           2.009828e+07              6.518165e+06
# 27        5.832977e+05           2.338915e+07              7.907488e+06
# 28        1.617963e+06           5.974591e+07              2.193395e+07
# 29        4.966323e+05           1.912089e+07              6.732607e+06
# 30        2.136540e+05           8.930850e+06              2.896405e+06
# 31        2.136540e+05           8.930850e+06              2.896405e+06
# 32        3.488270e+06           1.288100e+08              4.728881e+07
# 33        1.919486e+06           7.182184e+07              2.602155e+07
# 34        4.606303e+05           1.925459e+07              6.244545e+06
# 35        5.111938e+05           2.071747e+07              6.930009e+06

# %%
GROUP_COLS_all_metals = ['Demand scenario CER',
              'Production scenario CCI', 'Production scenario CCI|Refining CAN share',
              'Supply scenario']

df_cum_total_metal = (df_cum
    .groupby(GROUP_COLS_all_metals)[IMPACT_COLS]
    .sum()
    .reset_index()
                      )

# %%
# ── PARAMÈTRE À MODIFIER ──────────────────────────────────────────────────────
DEMAND_SCENARIO = 'Canada Net-zero'
# ─────────────────────────────────────────────────────────────────────────────

df_filtered = df_cum[df_cum['Demand scenario CER'] == DEMAND_SCENARIO].copy()

print(f'Scénario sélectionné : « {DEMAND_SCENARIO} »')
print(f'Lignes filtrées : {len(df_filtered)}')
print(f'Métaux : {df_filtered["Metal"].unique().tolist()}')
print(f'Supply scenarios : {df_filtered["Supply scenario"].unique().tolist()}')
df_filtered.head()
# Out:
# Scénario sélectionné : « Canada Net-zero »
# Lignes filtrées : 12
# Métaux : ['Cobalt', 'Copper', 'Nickel']
# Supply scenarios : ['NIMBY', 'Status Quo', 'Integrated', 'Expansion Extractive']
#      Metal Demand scenario CER Production scenario CCI  \
# 0   Cobalt     Canada Net-zero     Existing production
# 1   Cobalt     Canada Net-zero     Existing production
# 2   Cobalt     Canada Net-zero    Production potential
# 3   Cobalt     Canada Net-zero    Production potential
# 12  Copper     Canada Net-zero     Existing production
#
#    Production scenario CCI|Refining CAN share       Supply scenario  \
# 0                              Current shares                 NIMBY
# 1                              Current shares            Status Quo
# 2                                    100% CAN            Integrated
# 3                              Current shares  Expansion Extractive
# 12                             Current shares                 NIMBY
#
#     Total EQ (PDF.m2.yr)  Total HH (DALY)  \
# 0           1.642355e+07       151.710355
# 1           1.641252e+07       151.610231
# 2           1.636788e+07       151.204971
# 3           1.636963e+07       151.220748
# 12          9.527231e+08      1106.347640
#
#     Labor rights & decent work (physique)  Health & safety (physique)  \
# 0                            2.033158e+06                3.753363e+06
# 1                            2.017430e+06                3.724159e+06
# 2                            1.954004e+06                3.606267e+06
# 3                            1.956247e+06                3.610553e+06
# 12                           1.096970e+07                1.820136e+07
#
#     Society (physique)  Employment (physique)  IO multiplier (physique)
# 0         1.636539e+06            2130.301852              2.983295e+07
# 1         1.622783e+06            2109.622376              2.976494e+07
# 2         1.567296e+06            2028.934073              2.949975e+07
# 3         1.569271e+06            2029.178782              2.950039e+07
# 12        9.582401e+06           14143.361231              2.262583e+08

# %%
df_filtered_all_metals = df_cum_total_metal[df_cum_total_metal['Demand scenario CER'] == DEMAND_SCENARIO].copy()

# %% [markdown]
# ## 2. Fonctions de graphiques

# %%
import matplotlib.pyplot as plt

# %%
# Palette de couleurs par supply scenario
SUPPLY_COLORS = {
    'NIMBY'                          : '#E74C3C',
    'Status Quo'                     : '#F39C12',
    'Expansion Extractive'           : '#3498DB',
    'Expansion Extractive+Circularity': '#2ECC71',
    'Integrated'                     : '#9B59B6',
}

def plot_normalized_impacts(
    df_source,
    metal=None,
    demand_scenario=None,
    norm='max',          # 'max' | 'minmax' | 'zscore'
    figsize=(12, 5),
    title_suffix='',
    save_path=None,      # ex. 'figures/Cobalt_Canada_Net-zero.png'
):
    """
    Trace un graphique en barres groupées des impacts normalisés par indicateur
    pour un métal donné, en comparant les scénarios de supply.

    Paramètres
    ----------
    df_source      : DataFrame cumulé (issu de df_cum ou df_filtered)
    metal          : str, e.g. 'Cobalt'
    demand_scenario: str optionnel – filtre sur Demand scenario CER
    norm           : méthode de normalisation
                     'max'     → valeur / max(valeurs) de l'indicateur
                     'minmax'  → (valeur - min) / (max - min)
                     'zscore'  → (valeur - mean) / std
    figsize        : tuple
    title_suffix   : str ajouté au titre
    """
    data = df_source.copy()
    if metal is not None and 'Metal' in data.columns:
        data = data[data['Metal'] == metal]
    if demand_scenario:
        data = data[data['Demand scenario CER'] == demand_scenario]

    if data.empty:
        print(f'Aucune donnée pour metal={metal} / {demand_scenario}')
        return

    # Agréger par Supply scenario (somme si plusieurs prod. scenarios)
    data = data.groupby('Supply scenario')[IMPACT_COLS].sum()

    # Titre dynamique
    metal_label = metal if metal else 'All metals'

    # ── Normalisation ────────────────────────────────────────────────────────
    if norm == 'max':
        col_max = data.max(axis=0).replace(0, np.nan)
        data_norm = data.div(col_max, axis=1).fillna(0)
        ylabel = 'Impact normalisé (÷ max)'
    elif norm == 'minmax':
        col_min = data.min(axis=0)
        col_max = data.max(axis=0)
        denom = (col_max - col_min).replace(0, np.nan)
        data_norm = (data - col_min).div(denom, axis=1).fillna(0)
        ylabel = 'Impact normalisé min–max [0, 1]'
    elif norm == 'zscore':
        data_norm = data.apply(lambda col: (col - col.mean()) / col.std() if col.std() > 0 else col * 0)
        ylabel = 'Z-score'
    else:
        raise ValueError(f'norm doit être "max", "minmax" ou "zscore" (reçu: {norm!r})')

    # ── Tracé ─────────────────────────────────────────────────────────────────
    supply_scenarios = data_norm.index.tolist()
    n_indicators = len(IMPACT_COLS)
    n_supply = len(supply_scenarios)

    x = np.arange(n_indicators)
    width = 0.8 / n_supply
    offsets = np.linspace(-(n_supply - 1) / 2, (n_supply - 1) / 2, n_supply) * width

    fig, ax = plt.subplots(figsize=figsize)

    for i, scenario in enumerate(supply_scenarios):
        values = [data_norm.loc[scenario, col] for col in IMPACT_COLS]
        color  = SUPPLY_COLORS.get(scenario, f'C{i}')
        bars   = ax.bar(x + offsets[i], values, width=width * 0.92,
                        label=scenario, color=color, alpha=0.88, edgecolor='white', linewidth=0.5)

    # Axe X
    ax.set_xticks(x)
    ax.set_xticklabels([IMPACT_LABELS[c] for c in IMPACT_COLS], fontsize=10)

    # Lignes de référence
    if norm in ('max', 'minmax'):
        ax.axhline(1, color='black', linewidth=0.8, linestyle='--', alpha=0.4, label='Max')
        ax.set_ylim(0, 1.15)
    ax.axhline(0, color='black', linewidth=0.5, alpha=0.3)

    # Grille et style
    ax.set_axisbelow(True)
    ax.yaxis.grid(True, linestyle=':', alpha=0.6)
    ax.set_ylabel(ylabel, fontsize=11)
    ax.set_xlabel('Catégorie d\'impact', fontsize=11)

    demand_label = demand_scenario if demand_scenario else 'tous scénarios'
    ax.set_title(
        f'{metal_label}  ·  {demand_label}  ·  impacts cumulés 2025–2040{title_suffix}\n'
        f'Normalisation : {norm}',
        fontsize=12, fontweight='bold'
    )

    ax.legend(title='Supply scenario', bbox_to_anchor=(1.01, 1), loc='upper left',
              fontsize=9, title_fontsize=9, framealpha=0.9)

    plt.tight_layout()

    if save_path:
        fig.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f'Saved → {save_path}')

    plt.show()
    return fig

print('Fonction plot_normalized_impacts() définie ✓')
# Out:
# Fonction plot_normalized_impacts() définie ✓

# %%
import os
os.makedirs(r"for_SAM", exist_ok=True)

for metal in df_filtered['Metal'].unique():
    fname = f"for_SAM/{metal}_{DEMAND_SCENARIO.replace(' ', '_')}_max.png"
    plot_normalized_impacts(
        df_source=df_filtered,
        metal=metal,
        demand_scenario=DEMAND_SCENARIO,
        norm='max',
        save_path=fname,
    )
# Out:
# Saved → for_SAM/Cobalt_Canada_Net-zero_max.png
# Saved → for_SAM/Copper_Canada_Net-zero_max.png
# Saved → for_SAM/Nickel_Canada_Net-zero_max.png

# %%
plot_normalized_impacts(
        df_source=df_filtered_all_metals,
        #metal=metal,
        demand_scenario=DEMAND_SCENARIO,
        norm='max',
        save_path=r'all_metals',
    )
# Out:
# Saved → all_metals

# %%
df_filtered_all_metals
# Out:
#   Demand scenario CER Production scenario CCI  \
# 0     Canada Net-zero     Existing production
# 1     Canada Net-zero     Existing production
# 2     Canada Net-zero    Production potential
# 3     Canada Net-zero    Production potential
#
#   Production scenario CCI|Refining CAN share       Supply scenario  \
# 0                             Current shares                 NIMBY
# 1                             Current shares            Status Quo
# 2                                   100% CAN            Integrated
# 3                             Current shares  Expansion Extractive
#
#    Total EQ (PDF.m2.yr)  Total HH (DALY)  \
# 0          9.769895e+08      1332.574613
# 1          9.744493e+08      1270.192428
# 2          9.510667e+08      1089.972599
# 3          9.707659e+08      1175.895283
#
#    Labor rights & decent work (physique)  Health & safety (physique)  \
# 0                           1.744906e+07                3.187276e+07
# 1                           1.424090e+07                2.545836e+07
# 2                           9.766197e+06                1.700316e+07
# 3                           1.040064e+07                1.817967e+07
#
#    Society (physique)  Employment (physique)  IO multiplier (physique)
# 0        1.486006e+07           1.344704e+08              3.054521e+08
# 1        1.181773e+07           7.641203e+07              2.810937e+08
# 2        7.550081e+06           2.010743e+07              2.566993e+08
# 3        8.090066e+06           2.339881e+07              2.569740e+08
